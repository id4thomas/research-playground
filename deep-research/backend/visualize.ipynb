# %%
import sys
sys.path.append("src")

from agent.graphs.hf_paper_search.graph import graph as hf_paper_search_graph
from agent.graphs.deep_research.graph import graph as deep_research_graph

# %%
png_bytes = deep_research_graph.get_graph(xray=True).draw_mermaid_png()

with open("assets/deep_research_graph.png", "wb") as f:
    f.write(png_bytes)

# %%
png_bytes = hf_paper_search_graph.get_graph().draw_mermaid_png()

with open("assets/hf_paper_search_graph.png", "wb") as f:
    f.write(png_bytes)
